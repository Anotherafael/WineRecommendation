# %% [markdown]
# ### Importing the dataset

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
import joblib

# %%
df = pd.read_csv('../dataset/XWines_with_Ratings.csv', low_memory=False)

# %%
df.head()
# Out:
#    RatingID   UserID  Rating            WineName Vintage       Type  \
# 0    326545  1756594     4.0  Espumante Moscatel    1999  Sparkling
# 1   1314107  1219305     2.5  Espumante Moscatel    2007  Sparkling
# 2   1446366  2047929     3.5  Espumante Moscatel    2008  Sparkling
# 3   1448872  1006545     5.0  Espumante Moscatel    2008  Sparkling
# 4   1657104  1400823     2.0  Espumante Moscatel    2008  Sparkling
#
#        Elaborate  ABV          Body Acidity  ... Harmonize12         Grapes1  \
# 0  Varietal/100%  8.0  Mediumbodied    High  ...         NaN  Muscat/Moscato
# 1  Varietal/100%  8.0  Mediumbodied    High  ...         NaN  Muscat/Moscato
# 2  Varietal/100%  8.0  Mediumbodied    High  ...         NaN  Muscat/Moscato
# 3  Varietal/100%  8.0  Mediumbodied    High  ...         NaN  Muscat/Moscato
# 4  Varietal/100%  8.0  Mediumbodied    High  ...         NaN  Muscat/Moscato
#
#   Grapes2 Grapes3 Grapes4 Grapes5 Grapes6 Grapes7 Grapes8 Grapes9
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Creating a Pivot Table to Convert User Ratings to a Wide Format

# %%
df2 = pd.pivot_table(df, values=['Rating'],
                            index=['WineName', 'UserID'],
                            aggfunc='mean').unstack()
df2 = df2.fillna(0)
df2
# Out:
#                                                  Rating                  \
# UserID                                          1000004 1000010 1000021
# WineName
# 10 Anos Tawny Porto                                 0.0     0.0     0.0
# 10 Year Old Tawny Port                              3.5     0.0     0.0
# 10 Year Old Tawny Porto                             0.0     0.0     0.0
# 101 Moscato d Asti                                  0.0     0.0     0.0
# 12 e Mezzo Primitivo del Salento                    0.0     0.0     0.0
# ...                                                 ...     ...     ...
# Zweigelt Classic                                    0.0     0.0     0.0
# Zweigeltrebe                                        0.0     0.0     0.0
# Úrágya Tokaji Furmint                               0.0     0.0     0.0
# Ürziger Würzgarten Riesling Kabinett                0.0     0.0     0.0
# Красностоп Золотовский  Krasnostop Zolotovskiy      0.0     0.0     0.0
#
#                                                                          \
# UserID                                          1000023 1000024 1000025
# WineName
# 10 Anos Tawny Porto                                 0.0     0.0     0.0
# 10 Year Old Tawny Port                              0.0     0.0     4.0
# 10 Year Old Tawny Porto                             0.0     0.0     0.0
# 101 Moscato d Asti                                  0.0     0.0     0.0
# 12 e Mezzo Primitivo del Salento                    0.0     0.0     0.0
# ...                                                 ...     ...     ...
# Zweigelt Classic                                    0.0     0.0     0.0
# Zweigeltrebe                                        0.0     0.0     0.0
# Úrágya Tokaji Furmint                               0.0     0.0     0.0
# Ürziger Würzgarten Riesling Kabinett                0.0     0.0     0.0
# Красностоп Золотовский  Krasnostop Zolotovskiy      0.0     0.0     0.0
#
#                                                                          \
# UserID                                          1000027 1000029 1000031
# WineName
# 10 Anos Tawny Porto                                 0.0     0.0     0.0
# 10 Year Old Tawny Port                              0.0     0.0     0.0
# 10 Year Old Tawny Porto                             0.0     0.0     0.0
# 101 Moscato d Asti                                  0.0     0.0     0.0
# 12 e Mezzo Primitivo del Salento                    0.0     0.0     0.0
# ...                                                 ...     ...     ...
# Zweigelt Classic                                    0.0     0.0     0.0
# Zweigeltrebe                                        0.0     0.0     0.0
# Úrágya Tokaji Furmint                               0.0     0.0     0.0
# Ürziger Würzgarten Riesling Kabinett                0.0     0.0     0.0
# Красностоп Золотовский  Krasnostop Zolotovskiy      0.0     0.0     0.0
#
#                                                          ...                  \
# UserID                                          1000036  ... 2058533 2060068
# WineName                                                 ...
# 10 Anos Tawny Porto                                 0.0  ...     0.0     0.0
# 10 Year Old Tawny Port                              0.0  ...     0.0     0.0
# 10 Year Old Tawny Porto                             0.0  ...     0.0     0.0
# 101 Moscato d Asti                                  0.0  ...     0.0     0.0
# 12 e Mezzo Primitivo del Salento                    0.0  ...     0.0     0.0
# ...                                                 ...  ...     ...     ...
# Zweigelt Classic                                    0.0  ...     0.0     0.0
# Zweigeltrebe                                        0.0  ...     0.0     0.0
# Úrágya Tokaji Furmint                               0.0  ...     0.0     0.0
# Ürziger Würzgarten Riesling Kabinett                0.0  ...     0.0     0.0
# Красностоп Золотовский  Krasnostop Zolotovskiy      0.0  ...     0.0     0.0
#
#                                                                          \
# UserID                                          2060099 2060262 2060383
# WineName
# 10 Anos Tawny Porto                                 0.0     0.0     0.0
# 10 Year Old Tawny Port                              0.0     0.0     0.0
# 10 Year Old Tawny Porto                             0.0     0.0     0.0
# 101 Moscato d Asti                                  0.0     0.0     0.0
# 12 e Mezzo Primitivo del Salento                    0.0     0.0     0.0
# ...                                                 ...     ...     ...
# Zweigelt Classic                                    0.0     0.0     0.0
# Zweigeltrebe                                        0.0     0.0     0.0
# Úrágya Tokaji Furmint                               0.0     0.0     0.0
# Ürziger Würzgarten Riesling Kabinett                0.0     0.0     0.0
# Красностоп Золотовский  Krasnostop Zolotovskiy      0.0     0.0     0.0
#
#                                                                          \
# UserID                                          2061042 2061195 2062232
# WineName
# 10 Anos Tawny Porto                                 0.0     0.0     0.0
# 10 Year Old Tawny Port                              0.0     0.0     0.0
# 10 Year Old Tawny Porto                             0.0     0.0     0.0
# 101 Moscato d Asti                                  0.0     0.0     0.0
# 12 e Mezzo Primitivo del Salento                    0.0     0.0     0.0
# ...                                                 ...     ...     ...
# Zweigelt Classic                                    0.0     0.0     0.0
# Zweigeltrebe                                        0.0     0.0     0.0
# Úrágya Tokaji Furmint                               0.0     0.0     0.0
# Ürziger Würzgarten Riesling Kabinett                0.0     0.0     0.0
# Красностоп Золотовский  Krasnostop Zolotovskiy      0.0     0.0     0.0
#
#
# UserID                                          2062388 2062618
# WineName
# 10 Anos Tawny Porto                                 0.0     0.0
# 10 Year Old Tawny Port                              0.0     0.0
# 10 Year Old Tawny Porto                             0.0     0.0
# 101 Moscato d Asti                                  0.0     0.0
# 12 e Mezzo Primitivo del Salento                    0.0     0.0
# ...                                                 ...     ...
# Zweigelt Classic                                    0.0     0.0
# Zweigeltrebe                                        0.0     0.0
# Úrágya Tokaji Furmint                               0.0     0.0
# Ürziger Würzgarten Riesling Kabinett                0.0     0.0
# Красностоп Золотовский  Krasnostop Zolotovskiy      0.0     0.0
#
# [803 rows x 10561 columns]

# %% [markdown]
# ### Calculating Cosine Similarity and Euclidean Distance Matrices

# %%
cosine_sim = cosine_similarity(df2)
cosine_sim_df = pd.DataFrame(cosine_sim, index=df2.index, columns=df2.index)
cosine_sim_df
# Out:
# WineName                                         10 Anos Tawny Porto  \
# WineName
# 10 Anos Tawny Porto                                         1.000000
# 10 Year Old Tawny Port                                      0.045213
# 10 Year Old Tawny Porto                                     0.000000
# 101 Moscato d Asti                                          0.000000
# 12 e Mezzo Primitivo del Salento                            0.011653
# ...                                                              ...
# Zweigelt Classic                                            0.000000
# Zweigeltrebe                                                0.000000
# Úrágya Tokaji Furmint                                       0.000000
# Ürziger Würzgarten Riesling Kabinett                        0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy              0.018372
#
# WineName                                         10 Year Old Tawny Port  \
# WineName
# 10 Anos Tawny Porto                                            0.045213
# 10 Year Old Tawny Port                                         1.000000
# 10 Year Old Tawny Porto                                        0.025639
# 101 Moscato d Asti                                             0.047145
# 12 e Mezzo Primitivo del Salento                               0.073112
# ...                                                                 ...
# Zweigelt Classic                                               0.000000
# Zweigeltrebe                                                   0.018565
# Úrágya Tokaji Furmint                                          0.016206
# Ürziger Würzgarten Riesling Kabinett                           0.040775
# Красностоп Золотовский  Krasnostop Zolotovskiy                 0.028322
#
# WineName                                         10 Year Old Tawny Porto  \
# WineName
# 10 Anos Tawny Porto                                             0.000000
# 10 Year Old Tawny Port                                          0.025639
# 10 Year Old Tawny Porto                                         1.000000
# 101 Moscato d Asti                                              0.000000
# 12 e Mezzo Primitivo del Salento                                0.006419
# ...                                                                  ...
# Zweigelt Classic                                                0.000000
# Zweigeltrebe                                                    0.000000
# Úrágya Tokaji Furmint                                           0.000000
# Ürziger Würzgarten Riesling Kabinett                            0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy                  0.000000
#
# WineName                                         101 Moscato d Asti  \
# WineName
# 10 Anos Tawny Porto                                        0.000000
# 10 Year Old Tawny Port                                     0.047145
# 10 Year Old Tawny Porto                                    0.000000
# 101 Moscato d Asti                                         1.000000
# 12 e Mezzo Primitivo del Salento                           0.007088
# ...                                                             ...
# Zweigelt Classic                                           0.042447
# Zweigeltrebe                                               0.000000
# Úrágya Tokaji Furmint                                      0.000000
# Ürziger Würzgarten Riesling Kabinett                       0.021028
# Красностоп Золотовский  Krasnostop Zolotovskiy             0.020434
#
# WineName                                         12 e Mezzo Primitivo del Salento  \
# WineName
# 10 Anos Tawny Porto                                                      0.011653
# 10 Year Old Tawny Port                                                   0.073112
# 10 Year Old Tawny Porto                                                  0.006419
# 101 Moscato d Asti                                                       0.007088
# 12 e Mezzo Primitivo del Salento                                         1.000000
# ...                                                                           ...
# Zweigelt Classic                                                         0.013545
# Zweigeltrebe                                                             0.000000
# Úrágya Tokaji Furmint                                                    0.006284
# Ürziger Würzgarten Riesling Kabinett                                     0.006710
# Красностоп Золотовский  Krasnostop Zolotovskiy                           0.031559
#
# WineName                                         20 Anos Tawny Porto  \
# WineName
# 10 Anos Tawny Porto                                         0.000000
# 10 Year Old Tawny Port                                      0.010292
# 10 Year Old Tawny Porto                                     0.000000
# 101 Moscato d Asti                                          0.000000
# 12 e Mezzo Primitivo del Salento                            0.012885
# ...                                                              ...
# Zweigelt Classic                                            0.000000
# Zweigeltrebe                                                0.000000
# Úrágya Tokaji Furmint                                       0.000000
# Ürziger Würzgarten Riesling Kabinett                        0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy              0.000000
#
# WineName                                         20 Year Old Tawny Port  \
# WineName
# 10 Anos Tawny Porto                                            0.021286
# 10 Year Old Tawny Port                                         0.062177
# 10 Year Old Tawny Porto                                        0.023941
# 101 Moscato d Asti                                             0.031213
# 12 e Mezzo Primitivo del Salento                               0.038477
# ...                                                                 ...
# Zweigelt Classic                                               0.000000
# Zweigeltrebe                                                   0.000000
# Úrágya Tokaji Furmint                                          0.000000
# Ürziger Würzgarten Riesling Kabinett                           0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy                 0.000000
#
# WineName                                         20 Years Old Tawny Porto  \
# WineName
# 10 Anos Tawny Porto                                              0.000000
# 10 Year Old Tawny Port                                           0.043146
# 10 Year Old Tawny Porto                                          0.000000
# 101 Moscato d Asti                                               0.000000
# 12 e Mezzo Primitivo del Salento                                 0.011343
# ...                                                                   ...
# Zweigelt Classic                                                 0.000000
# Zweigeltrebe                                                     0.000000
# Úrágya Tokaji Furmint                                            0.000000
# Ürziger Würzgarten Riesling Kabinett                             0.029911
# Красностоп Золотовский  Krasnostop Zolotovskiy                   0.000000
#
# WineName                                         21 Gables Chenin Blanc  \
# WineName
# 10 Anos Tawny Porto                                            0.038204
# 10 Year Old Tawny Port                                         0.061025
# 10 Year Old Tawny Porto                                        0.000000
# 101 Moscato d Asti                                             0.039055
# 12 e Mezzo Primitivo del Salento                               0.033697
# ...                                                                 ...
# Zweigelt Classic                                               0.041141
# Zweigeltrebe                                                   0.023530
# Úrágya Tokaji Furmint                                          0.031023
# Ürziger Würzgarten Riesling Kabinett                           0.054026
# Красностоп Золотовский  Krasnostop Zolotovskiy                 0.017604
#
# WineName                                         A Galet Rosado  ...  \
# WineName                                                         ...
# 10 Anos Tawny Porto                                    0.000000  ...
# 10 Year Old Tawny Port                                 0.000000  ...
# 10 Year Old Tawny Porto                                0.000000  ...
# 101 Moscato d Asti                                     0.000000  ...
# 12 e Mezzo Primitivo del Salento                       0.010544  ...
# ...                                                         ...  ...
# Zweigelt Classic                                       0.000000  ...
# Zweigeltrebe                                           0.000000  ...
# Úrágya Tokaji Furmint                                  0.000000  ...
# Ürziger Würzgarten Riesling Kabinett                   0.000000  ...
# Красностоп Золотовский  Krasnostop Zolotovskiy         0.000000  ...
#
# WineName                                         Winemaker s Collection Blanc de Noir  \
# WineName
# 10 Anos Tawny Porto                                                          0.000000
# 10 Year Old Tawny Port                                                       0.000000
# 10 Year Old Tawny Porto                                                      0.000000
# 101 Moscato d Asti                                                           0.000000
# 12 e Mezzo Primitivo del Salento                                             0.016346
# ...                                                                               ...
# Zweigelt Classic                                                             0.000000
# Zweigeltrebe                                                                 0.000000
# Úrágya Tokaji Furmint                                                        0.000000
# Ürziger Würzgarten Riesling Kabinett                                         0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy                               0.000000
#
# WineName                                         Winemaker s Collection Montepulciano d Abruzzo  \
# WineName
# 10 Anos Tawny Porto                                                                    0.000000
# 10 Year Old Tawny Port                                                                 0.007823
# 10 Year Old Tawny Porto                                                                0.000000
# 101 Moscato d Asti                                                                     0.000000
# 12 e Mezzo Primitivo del Salento                                                       0.008747
# ...                                                                                         ...
# Zweigelt Classic                                                                       0.000000
# Zweigeltrebe                                                                           0.000000
# Úrágya Tokaji Furmint                                                                  0.000000
# Ürziger Würzgarten Riesling Kabinett                                                   0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy                                         0.000000
#
# WineName                                         Woodthorpe Vineyard Syrah  \
# WineName
# 10 Anos Tawny Porto                                               0.000000
# 10 Year Old Tawny Port                                            0.031786
# 10 Year Old Tawny Porto                                           0.000000
# 101 Moscato d Asti                                                0.064360
# 12 e Mezzo Primitivo del Salento                                  0.016848
# ...                                                                    ...
# Zweigelt Classic                                                  0.000000
# Zweigeltrebe                                                      0.000000
# Úrágya Tokaji Furmint                                             0.112958
# Ürziger Würzgarten Riesling Kabinett                              0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy                    0.021248
#
# WineName                                         Zinfandel  Zweigelt  \
# WineName
# 10 Anos Tawny Porto                                0.00000  0.000000
# 10 Year Old Tawny Port                             0.01283  0.008708
# 10 Year Old Tawny Porto                            0.00000  0.061881
# 101 Moscato d Asti                                 0.00000  0.000000
# 12 e Mezzo Primitivo del Salento                   0.00000  0.005451
# ...                                                    ...       ...
# Zweigelt Classic                                   0.00000  0.000000
# Zweigeltrebe                                       0.00000  0.000000
# Úrágya Tokaji Furmint                              0.00000  0.000000
# Ürziger Würzgarten Riesling Kabinett               0.00000  0.063673
# Красностоп Золотовский  Krasnostop Zolotovskiy     0.00000  0.000000
#
# WineName                                         Zweigelt Classic  \
# WineName
# 10 Anos Tawny Porto                                      0.000000
# 10 Year Old Tawny Port                                   0.000000
# 10 Year Old Tawny Porto                                  0.000000
# 101 Moscato d Asti                                       0.042447
# 12 e Mezzo Primitivo del Salento                         0.013545
# ...                                                           ...
# Zweigelt Classic                                         1.000000
# Zweigeltrebe                                             0.000000
# Úrágya Tokaji Furmint                                    0.000000
# Ürziger Würzgarten Riesling Kabinett                     0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy           0.000000
#
# WineName                                         Zweigeltrebe  \
# WineName
# 10 Anos Tawny Porto                                  0.000000
# 10 Year Old Tawny Port                               0.018565
# 10 Year Old Tawny Porto                              0.000000
# 101 Moscato d Asti                                   0.000000
# 12 e Mezzo Primitivo del Salento                     0.000000
# ...                                                       ...
# Zweigelt Classic                                     0.000000
# Zweigeltrebe                                         1.000000
# Úrágya Tokaji Furmint                                0.000000
# Ürziger Würzgarten Riesling Kabinett                 0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy       0.000000
#
# WineName                                         Úrágya Tokaji Furmint  \
# WineName
# 10 Anos Tawny Porto                                           0.000000
# 10 Year Old Tawny Port                                        0.016206
# 10 Year Old Tawny Porto                                       0.000000
# 101 Moscato d Asti                                            0.000000
# 12 e Mezzo Primitivo del Salento                              0.006284
# ...                                                                ...
# Zweigelt Classic                                              0.000000
# Zweigeltrebe                                                  0.000000
# Úrágya Tokaji Furmint                                         1.000000
# Ürziger Würzgarten Riesling Kabinett                          0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy                0.000000
#
# WineName                                         Ürziger Würzgarten Riesling Kabinett  \
# WineName
# 10 Anos Tawny Porto                                                          0.000000
# 10 Year Old Tawny Port                                                       0.040775
# 10 Year Old Tawny Porto                                                      0.000000
# 101 Moscato d Asti                                                           0.021028
# 12 e Mezzo Primitivo del Salento                                             0.006710
# ...                                                                               ...
# Zweigelt Classic                                                             0.000000
# Zweigeltrebe                                                                 0.000000
# Úrágya Tokaji Furmint                                                        0.000000
# Ürziger Würzgarten Riesling Kabinett                                         1.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy                               0.000000
#
# WineName                                         Красностоп Золотовский  Krasnostop Zolotovskiy
# WineName
# 10 Anos Tawny Porto                                                                     0.018372
# 10 Year Old Tawny Port                                                                  0.028322
# 10 Year Old Tawny Porto                                                                 0.000000
# 101 Moscato d Asti                                                                      0.020434
# 12 e Mezzo Primitivo del Salento                                                        0.031559
# ...                                                                                          ...
# Zweigelt Classic                                                                        0.000000
# Zweigeltrebe                                                                            0.000000
# Úrágya Tokaji Furmint                                                                   0.000000
# Ürziger Würzgarten Riesling Kabinett                                                    0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy                                          1.000000
#
# [803 rows x 803 columns]

# %%
dist_euc = euclidean_distances(df2)
dist_euc_df = pd.DataFrame(dist_euc, index=df2.index, columns=df2.index)
dist_euc_df
# Out:
# WineName                                         10 Anos Tawny Porto  \
# WineName
# 10 Anos Tawny Porto                                         0.000000
# 10 Year Old Tawny Port                                     92.834530
# 10 Year Old Tawny Porto                                    19.748418
# 101 Moscato d Asti                                         28.600699
# 12 e Mezzo Primitivo del Salento                           85.486841
# ...                                                              ...
# Zweigelt Classic                                           21.534855
# Zweigeltrebe                                               18.261982
# Úrágya Tokaji Furmint                                      24.989998
# Ürziger Würzgarten Riesling Kabinett                       32.714676
# Красностоп Золотовский  Krasnostop Zolotovskiy             36.854443
#
# WineName                                         10 Year Old Tawny Port  \
# WineName
# 10 Anos Tawny Porto                                           92.834530
# 10 Year Old Tawny Port                                         0.000000
# 10 Year Old Tawny Porto                                       92.513513
# 101 Moscato d Asti                                            93.996011
# 12 e Mezzo Primitivo del Salento                             120.117651
# ...                                                                 ...
# Zweigelt Classic                                              93.193347
# Zweigeltrebe                                                  92.340403
# Úrágya Tokaji Furmint                                         93.751000
# Ürziger Würzgarten Riesling Kabinett                          95.281163
# Красностоп Золотовский  Krasnostop Zolotovskiy                97.085014
#
# WineName                                         10 Year Old Tawny Porto  \
# WineName
# 10 Anos Tawny Porto                                            19.748418
# 10 Year Old Tawny Port                                         92.513513
# 10 Year Old Tawny Porto                                         0.000000
# 101 Moscato d Asti                                             25.980762
# 12 e Mezzo Primitivo del Salento                               84.764379
# ...                                                                  ...
# Zweigelt Classic                                               17.909495
# Zweigeltrebe                                                   13.802174
# Úrágya Tokaji Furmint                                          21.943108
# Ürziger Würzgarten Riesling Kabinett                           30.450780
# Красностоп Золотовский  Krasnostop Zolotovskiy                 35.146124
#
# WineName                                         101 Moscato d Asti  \
# WineName
# 10 Anos Tawny Porto                                       28.600699
# 10 Year Old Tawny Port                                    93.996011
# 10 Year Old Tawny Porto                                   25.980762
# 101 Moscato d Asti                                         0.000000
# 12 e Mezzo Primitivo del Salento                          87.160771
# ...                                                             ...
# Zweigelt Classic                                          26.846788
# Zweigeltrebe                                              24.869660
# Úrágya Tokaji Furmint                                     30.157918
# Ürziger Würzgarten Riesling Kabinett                      36.431442
# Красностоп Золотовский  Krasnostop Zolotovskiy            40.388736
#
# WineName                                         12 e Mezzo Primitivo del Salento  \
# WineName
# 10 Anos Tawny Porto                                                     85.486841
# 10 Year Old Tawny Port                                                 120.117651
# 10 Year Old Tawny Porto                                                 84.764379
# 101 Moscato d Asti                                                      87.160771
# 12 e Mezzo Primitivo del Salento                                         0.000000
# ...                                                                           ...
# Zweigelt Classic                                                        85.080844
# Zweigeltrebe                                                            84.501479
# Úrágya Tokaji Furmint                                                   86.090069
# Ürziger Würzgarten Riesling Kabinett                                    88.573416
# Красностоп Золотовский  Krasnostop Zolotovskiy                          89.488826
#
# WineName                                         20 Anos Tawny Porto  \
# WineName
# 10 Anos Tawny Porto                                        22.011361
# 10 Year Old Tawny Port                                     93.154442
# 10 Year Old Tawny Porto                                    18.479719
# 101 Moscato d Asti                                         27.739863
# 12 e Mezzo Primitivo del Salento                           85.202699
# ...                                                              ...
# Zweigelt Classic                                           20.377684
# Zweigeltrebe                                               16.881943
# Úrágya Tokaji Furmint                                      24.000000
# Ürziger Würzgarten Riesling Kabinett                       31.964824
# Красностоп Золотовский  Krasnostop Zolotovskiy             36.465737
#
# WineName                                         20 Year Old Tawny Port  \
# WineName
# 10 Anos Tawny Porto                                           48.523190
# 10 Year Old Tawny Port                                       100.400448
# 10 Year Old Tawny Porto                                       47.106263
# 101 Moscato d Asti                                            51.029403
# 12 e Mezzo Primitivo del Salento                              94.315958
# ...                                                                 ...
# Zweigelt Classic                                              48.137823
# Zweigeltrebe                                                  46.765372
# Úrágya Tokaji Furmint                                         49.779514
# Ürziger Würzgarten Riesling Kabinett                          54.071712
# Красностоп Золотовский  Krasnostop Zolotovskiy                56.848483
#
# WineName                                         20 Years Old Tawny Porto  \
# WineName
# 10 Anos Tawny Porto                                             24.949950
# 10 Year Old Tawny Port                                          93.240281
# 10 Year Old Tawny Porto                                         21.897488
# 101 Moscato d Asti                                              30.124741
# 12 e Mezzo Primitivo del Salento                                85.985464
# ...                                                                   ...
# Zweigelt Classic                                                23.521267
# Zweigeltrebe                                                    20.566964
# Úrágya Tokaji Furmint                                           26.720778
# Ürziger Würzgarten Riesling Kabinett                            33.581989
# Красностоп Золотовский  Krasnostop Zolotovskiy                  38.311226
#
# WineName                                         21 Gables Chenin Blanc  \
# WineName
# 10 Anos Tawny Porto                                           56.307193
# 10 Year Old Tawny Port                                       104.147732
# 10 Year Old Tawny Porto                                       55.637218
# 101 Moscato d Asti                                            58.510683
# 12 e Mezzo Primitivo del Salento                              98.673705
# ...                                                                 ...
# Zweigelt Classic                                              55.733742
# Zweigeltrebe                                                  54.936327
# Úrágya Tokaji Furmint                                         57.148928
# Ürziger Würzgarten Riesling Kabinett                          60.072872
# Красностоп Золотовский  Krasnostop Zolotovskiy                63.401498
#
# WineName                                         A Galet Rosado  ...  \
# WineName                                                         ...
# 10 Anos Tawny Porto                                   22.710130  ...
# 10 Year Old Tawny Port                                93.471921  ...
# 10 Year Old Tawny Porto                               19.306735  ...
# 101 Moscato d Asti                                    28.297526  ...
# 12 e Mezzo Primitivo del Salento                      85.409309  ...
# ...                                                         ...  ...
# Zweigelt Classic                                      21.130547  ...
# Zweigeltrebe                                          17.783419  ...
# Úrágya Tokaji Furmint                                 24.642443  ...
# Ürziger Würzgarten Riesling Kabinett                  32.449961  ...
# Красностоп Золотовский  Krasnostop Zolotovskiy        36.891733  ...
#
# WineName                                         Winemaker s Collection Blanc de Noir  \
# WineName
# 10 Anos Tawny Porto                                                         19.943671
# 10 Year Old Tawny Port                                                      92.838570
# 10 Year Old Tawny Porto                                                     15.960890
# 101 Moscato d Asti                                                          26.129485
# 12 e Mezzo Primitivo del Salento                                            84.695041
# ...                                                                               ...
# Zweigelt Classic                                                            18.124569
# Zweigeltrebe                                                                14.080128
# Úrágya Tokaji Furmint                                                       22.118996
# Ürziger Würzgarten Riesling Kabinett                                        30.577770
# Красностоп Золотовский  Krasnostop Zolotovskiy                              35.256205
#
# WineName                                         Winemaker s Collection Montepulciano d Abruzzo  \
# WineName
# 10 Anos Tawny Porto                                                                   23.318448
# 10 Year Old Tawny Port                                                                93.493315
# 10 Year Old Tawny Porto                                                               20.018741
# 101 Moscato d Asti                                                                    28.788018
# 12 e Mezzo Primitivo del Salento                                                      85.593516
# ...                                                                                         ...
# Zweigelt Classic                                                                      21.783021
# Zweigeltrebe                                                                          18.553975
# Úrágya Tokaji Furmint                                                                 25.204166
# Ürziger Würzgarten Riesling Kabinett                                                  32.878564
# Красностоп Золотовский  Krasnostop Zolotovskiy                                        37.269290
#
# WineName                                         Woodthorpe Vineyard Syrah  \
# WineName
# 10 Anos Tawny Porto                                              26.734809
# 10 Year Old Tawny Port                                           93.872254
# 10 Year Old Tawny Porto                                          23.911294
# 101 Moscato d Asti                                               30.590031
# 12 e Mezzo Primitivo del Salento                                 86.381422
# ...                                                                    ...
# Zweigelt Classic                                                 25.406692
# Zweigeltrebe                                                     22.699119
# Úrágya Tokaji Furmint                                            26.753504
# Ürziger Würzgarten Riesling Kabinett                             35.383612
# Красностоп Золотовский  Krasnostop Zolotovskiy                   39.115214
#
# WineName                                         Zinfandel   Zweigelt  \
# WineName
# 10 Anos Tawny Porto                              26.052831  23.895606
# 10 Year Old Tawny Port                           94.085068  93.617573
# 10 Year Old Tawny Porto                          23.146274  20.099751
# 101 Moscato d Asti                               31.044323  29.257478
# 12 e Mezzo Primitivo del Salento                 86.520229  85.802098
# ...                                                    ...        ...
# Zweigelt Classic                                 24.688054  22.399777
# Zweigeltrebe                                     21.891779  19.274335
# Úrágya Tokaji Furmint                            27.753378  25.739075
# Ürziger Würzgarten Riesling Kabinett             34.871192  32.330326
# Красностоп Золотовский  Krasnostop Zolotovskiy   39.038443  37.633097
#
# WineName                                         Zweigelt Classic  \
# WineName
# 10 Anos Tawny Porto                                     21.534855
# 10 Year Old Tawny Port                                  93.193347
# 10 Year Old Tawny Porto                                 17.909495
# 101 Moscato d Asti                                      26.846788
# 12 e Mezzo Primitivo del Salento                        85.080844
# ...                                                           ...
# Zweigelt Classic                                         0.000000
# Zweigeltrebe                                            16.255768
# Úrágya Tokaji Furmint                                   23.563743
# Ürziger Würzgarten Riesling Kabinett                    31.638584
# Красностоп Золотовский  Krasnostop Zolotovskiy          36.180105
#
# WineName                                         Zweigeltrebe  \
# WineName
# 10 Anos Tawny Porto                                 18.261982
# 10 Year Old Tawny Port                              92.340403
# 10 Year Old Tawny Porto                             13.802174
# 101 Moscato d Asti                                  24.869660
# 12 e Mezzo Primitivo del Salento                    84.501479
# ...                                                       ...
# Zweigelt Classic                                    16.255768
# Zweigeltrebe                                         0.000000
# Úrágya Tokaji Furmint                               20.615528
# Ürziger Würzgarten Riesling Kabinett                29.508473
# Красностоп Золотовский  Krasnostop Zolotovskiy      34.332929
#
# WineName                                         Úrágya Tokaji Furmint  \
# WineName
# 10 Anos Tawny Porto                                          24.989998
# 10 Year Old Tawny Port                                       93.751000
# 10 Year Old Tawny Porto                                      21.943108
# 101 Moscato d Asti                                           30.157918
# 12 e Mezzo Primitivo del Salento                             86.090069
# ...                                                                ...
# Zweigelt Classic                                             23.563743
# Zweigeltrebe                                                 20.615528
# Úrágya Tokaji Furmint                                         0.000000
# Ürziger Würzgarten Riesling Kabinett                         34.084454
# Красностоп Золотовский  Krasnostop Zolotovskiy               38.337319
#
# WineName                                         Ürziger Würzgarten Riesling Kabinett  \
# WineName
# 10 Anos Tawny Porto                                                         32.714676
# 10 Year Old Tawny Port                                                      95.281163
# 10 Year Old Tawny Porto                                                     30.450780
# 101 Moscato d Asti                                                          36.431442
# 12 e Mezzo Primitivo del Salento                                            88.573416
# ...                                                                               ...
# Zweigelt Classic                                                            31.638584
# Zweigeltrebe                                                                29.508473
# Úrágya Tokaji Furmint                                                       34.084454
# Ürziger Würzgarten Riesling Kabinett                                         0.000000
# Красностоп Золотовский  Krasnostop Zolotovskiy                              43.766425
#
# WineName                                         Красностоп Золотовский  Krasnostop Zolotovskiy
# WineName
# 10 Anos Tawny Porto                                                                    36.854443
# 10 Year Old Tawny Port                                                                 97.085014
# 10 Year Old Tawny Porto                                                                35.146124
# 101 Moscato d Asti                                                                     40.388736
# 12 e Mezzo Primitivo del Salento                                                       89.488826
# ...                                                                                          ...
# Zweigelt Classic                                                                       36.180105
# Zweigeltrebe                                                                           34.332929
# Úrágya Tokaji Furmint                                                                  38.337319
# Ürziger Würzgarten Riesling Kabinett                                                   43.766425
# Красностоп Золотовский  Krasnostop Zolotovskiy                                          0.000000
#
# [803 rows x 803 columns]

# %% [markdown]
# ### Testing the Model

# %%
def find_similar_wines_combined(wines, count=10):
    recommendation = {}

    wines_cosine = [wine for wine in wines if wine in cosine_sim_df.columns]
    wines_summed_cosine = cosine_sim_df[wines_cosine].apply(lambda row: np.sum(row), axis=1)
    wines_summed_cosine = wines_summed_cosine.sort_values(ascending=False)
    ranked_wines_cosine = wines_summed_cosine.index[wines_summed_cosine.index.isin(wines_cosine) == False]
    ranked_wines_cosine = ranked_wines_cosine.tolist()
    ranked_wines_cosine = ranked_wines_cosine[:count]

    wines_euclidean = [wine for wine in wines if wine in dist_euc_df.columns]
    wines_summed_euclidean = dist_euc_df[wines_euclidean].apply(lambda row: np.sum(row), axis=1)
    wines_summed_euclidean = wines_summed_euclidean.sort_values()
    ranked_wines_euclidean = wines_summed_euclidean.index[wines_summed_euclidean.index.isin(wines_euclidean) == False]
    ranked_wines_euclidean = ranked_wines_euclidean.tolist()
    ranked_wines_euclidean = ranked_wines_euclidean[:count]

    combined_ranking = {}
    for i, wine in enumerate(ranked_wines_cosine):
        combined_ranking[wine] = combined_ranking.get(wine, 0) + i

    for i, wine in enumerate(ranked_wines_euclidean):
        combined_ranking[wine] = combined_ranking.get(wine, 0) + i

    sorted_combined_ranking = sorted(combined_ranking.items(), key=lambda x: x[1])

    top_10_wine_indices = [df.index[df['WineName'] == wine].tolist()[0] for wine, _ in sorted_combined_ranking[:count]]
    top_10_wines = df.loc[top_10_wine_indices, ['WineName']].copy()

    recommendation = {
        'WineName': df['WineName'].iloc[top_10_wine_indices],
    }

    return pd.DataFrame(recommendation)

# %%
name = df['WineName'].sample(1).values[0]

# %%
display(f'Recommendation for: {name}')
find_similar_wines_combined(['Vecchia Grappa Moscato'], 10)
# Out:
# 'Recommendation for: Rouge  Gaston Hochar '
#                                WineName
# 8897               STORIA Grappa Merlot
# 1683            Cave Cabernet Sauvignon
# 76810                     Garnacha Rosé
# 114947       A Rosé Is A Rosé Is A Rosé
# 149986      Grüner Veltliner Alte Reben
# 75832                        Perlé Nero
# 76771                         Fragolino
# 8308                 Reserva Chardonnay
# 24787      Trollinger Lemberger Trocken
# 7279    Colheita Tardia Malvasia Bianca

# %% [markdown]
# ### Exporting the model

# %%
joblib.dump((cosine_sim_df, dist_euc_df, df), '../models/collaborative_recommender_model.pkl', compress=('zlib', 3))
# Out:
# ['../models/collaborative_recommender_model.pkl']
